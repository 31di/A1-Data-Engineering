# %%
import vectorization as v
def main():
    bag_of_words = ["the", "cat", "sat", "on", "mat"]
    text = ["the cat mat"]
    vector = v.change_text_to_vector(text, bag_of_words)
    print(vector)

# %%
main()
# Out:
# [1 1 0 0 1]
